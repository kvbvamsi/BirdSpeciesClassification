# %% [markdown]
# # BIRD SPECIES CLASSIFICATION with DEEP LEARNING

# %% [markdown]
# <p style="text-align:center;"><img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR-zuTVRKn8MQ4ZiHcK-WU1QoCzoYw_V7Yh9g&usqp=CAU" alt="Girl in a jacket" width="500" height="600" class="center"></p>

# %% [markdown]
# **Project Overview**
#
# It is a project that uses transfer learning to predict 450 classes belonging to bird species. Data set of 400 bird species.58388 training images, 2000 test images(5 images per species) and 2000 validation images(5 images per species. This is a very high quality dataset where there is only one bird in each image and the bird typically takes up at least 50% of the pixels in the image. As a result even a moderatly complex model will achieve training and test accuracies in the mid 90% range.
#
# To become one with data is significant in such projects. Therefore, visualization techniques are usually applied in the project. A pre-trained model of Keras (InceptionV3) is  used in the project. After reachin nearly %89 accuracy, fine-tuning is applied and the accuracy is improved to **%94**.
#
# Steps followed during the development of the project:
#
# * 1. Become One with Data
# * 2. Data Preprocessing
# * 3. Create a and fit the Model (Using InceptionV3 pre-trained model)
# * 4. Freeze top layers of Base Model
# * 5. Fine-tuning and Refitting

# %% [markdown]
# ## 1. Become one with the data

# %%
import os 

#walk through the directory and list the numbers of files
for dirpath, dirnames, filenames in os.walk(r"C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in {dirpath}")
# Out:
# There are 4 directories and 3 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\images to test
# There are 450 directories and 0 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ABBOTTS BABBLER
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ABBOTTS BOOBY
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ABYSSINIAN GROUND HORNBILL
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AFRICAN CROWNED CRANE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AFRICAN EMERALD CUCKOO
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AFRICAN FIREFINCH
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AFRICAN OYSTER CATCHER
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AFRICAN PIED HORNBILL
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ALBATROSS
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ALBERTS TOWHEE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ALEXANDRINE PARAKEET
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ALPINE CHOUGH
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ALTAMIRA YELLOWTHROAT
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AMERICAN AVOCET
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AMERICAN BITTERN
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AMERICAN COOT
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AMERICAN FLAMINGO
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AMERICAN GOLDFINCH
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AMERICAN KESTREL
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AMERICAN PIPIT
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AMERICAN REDSTART
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AMERICAN WIGEON
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AMETHYST WOODSTAR
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ANDEAN GOOSE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ANDEAN LAPWING
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ANDEAN SISKIN
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ANHINGA
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ANIANIAU
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ANNAS HUMMINGBIRD
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ANTBIRD
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ANTILLEAN EUPHONIA
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\APAPANE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\APOSTLEBIRD
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ARARIPE MANAKIN
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ASHY STORM PETREL
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ASHY THRUSHBIRD
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ASIAN CRESTED IBIS
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\ASIAN DOLLARD BIRD
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AUCKLAND SHAQ
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AUSTRAL CANASTERO
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AUSTRALASIAN FIGBIRD
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AVADAVAT
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AZARAS SPINETAIL
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AZURE BREASTED PITTA
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AZURE JAY
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AZURE TANAGER
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\AZURE TIT
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\BAIKAL TEAL
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\BALD EAGLE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\BALD IBIS
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\BALI STARLING
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\BALTIMORE ORIOLE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\BANANAQUIT
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\BAND TAILED GUAN
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\BANDED BROADBILL
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\BANDED PITA
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test\BANDED STILT
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\test
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\STEAMER DUCK
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\STORK BILLED KINGFISHER
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\STRAWBERRY FINCH
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\STRIPED OWL
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\STRIPPED MANAKIN
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\STRIPPED SWALLOW
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\SUPERB STARLING
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\SWINHOES PHEASANT
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TAILORBIRD
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TAIWAN MAGPIE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TAKAHE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TASMANIAN HEN
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TEAL DUCK
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TIT MOUSE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TOUCHAN
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TOWNSENDS WARBLER
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TREE SWALLOW
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TRICOLORED BLACKBIRD
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TROPICAL KINGBIRD
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TRUMPTER SWAN
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TURKEY VULTURE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\TURQUOISE MOTMOT
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\UMBRELLA BIRD
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\VARIED THRUSH
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\VEERY
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\VENEZUELIAN TROUPIAL
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\VERMILION FLYCATHER
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\VICTORIA CROWNED PIGEON
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\VIOLET GREEN SWALLOW
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\VIOLET TURACO
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\VULTURINE GUINEAFOWL
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WALL CREAPER
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WATTLED CURASSOW
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WATTLED LAPWING
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WHIMBREL
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WHITE BROWED CRAKE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WHITE CHEEKED TURACO
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WHITE CRESTED HORNBILL
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WHITE NECKED RAVEN
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WHITE TAILED TROPIC
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WHITE THROATED BEE EATER
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WILD TURKEY
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WILSONS BIRD OF PARADISE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\WOOD DUCK
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\YELLOW BELLIED FLOWERPECKER
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\YELLOW CACIQUE
# There are 0 directories and 5 images in C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\valid\YELLOW HEADED BLACKBIRD

# %% [markdown]
# ##### How many classes do we have?

# %%
num_of_bird_groups = len(os.listdir(r'C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\train'))
num_of_bird_groups
# Out:
# 450

# %% [markdown]
# ##### What are the class names?

# %%
import pathlib 
import numpy as np

data_dir = pathlib.Path(r"C:\Users\Ravindra KVB\Desktop\vamsi\B.TEC\IDP\New folder\train")
class_names = np.array(sorted([item.name for item in data_dir.glob("*")])) # creating a list of class names from subdirectory 
print(class_names)
# Out:
# ['ABBOTTS BABBLER' 'ABBOTTS BOOBY' 'ABYSSINIAN GROUND HORNBILL'
#  'AFRICAN CROWNED CRANE' 'AFRICAN EMERALD CUCKOO' 'AFRICAN FIREFINCH'
#  'AFRICAN OYSTER CATCHER' 'AFRICAN PIED HORNBILL' 'ALBATROSS'
#  'ALBERTS TOWHEE' 'ALEXANDRINE PARAKEET' 'ALPINE CHOUGH'
#  'ALTAMIRA YELLOWTHROAT' 'AMERICAN AVOCET' 'AMERICAN BITTERN'
#  'AMERICAN COOT' 'AMERICAN FLAMINGO' 'AMERICAN GOLDFINCH'
#  'AMERICAN KESTREL' 'AMERICAN PIPIT' 'AMERICAN REDSTART' 'AMERICAN WIGEON'
#  'AMETHYST WOODSTAR' 'ANDEAN GOOSE' 'ANDEAN LAPWING' 'ANDEAN SISKIN'
#  'ANHINGA' 'ANIANIAU' 'ANNAS HUMMINGBIRD' 'ANTBIRD' 'ANTILLEAN EUPHONIA'
#  'APAPANE' 'APOSTLEBIRD' 'ARARIPE MANAKIN' 'ASHY STORM PETREL'
#  'ASHY THRUSHBIRD' 'ASIAN CRESTED IBIS' 'ASIAN DOLLARD BIRD'
#  'AUCKLAND SHAQ' 'AUSTRAL CANASTERO' 'AUSTRALASIAN FIGBIRD' 'AVADAVAT'
#  'AZARAS SPINETAIL' 'AZURE BREASTED PITTA' 'AZURE JAY' 'AZURE TANAGER'
#  'AZURE TIT' 'BAIKAL TEAL' 'BALD EAGLE' 'BALD IBIS' 'BALI STARLING'
#  'BALTIMORE ORIOLE' 'BANANAQUIT' 'BAND TAILED GUAN' 'BANDED BROADBILL'
#  'BANDED PITA' 'BANDED STILT' 'BAR-TAILED GODWIT' 'BARN OWL'
#  'BARN SWALLOW' 'BARRED PUFFBIRD' 'BARROWS GOLDENEYE'
#  'BAY-BREASTED WARBLER' 'BEARDED BARBET' 'BEARDED BELLBIRD'
#  'BEARDED REEDLING' 'BELTED KINGFISHER' 'BIRD OF PARADISE'
#  'BLACK & YELLOW BROADBILL' 'BLACK BAZA' 'BLACK COCKATO' 'BLACK FRANCOLIN'
#  'BLACK SKIMMER' 'BLACK SWAN' 'BLACK TAIL CRAKE' 'BLACK THROATED BUSHTIT'
#  'BLACK THROATED WARBLER' 'BLACK VENTED SHEARWATER' 'BLACK VULTURE'
#  'BLACK-CAPPED CHICKADEE' 'BLACK-NECKED GREBE' 'BLACK-THROATED SPARROW'
#  'BLACKBURNIAM WARBLER' 'BLONDE CRESTED WOODPECKER' 'BLOOD PHEASANT'
#  'BLUE COAU' 'BLUE DACNIS' 'BLUE GROUSE' 'BLUE HERON' 'BLUE MALKOHA'
#  'BLUE THROATED TOUCANET' 'BOBOLINK' 'BORNEAN BRISTLEHEAD'
#  'BORNEAN LEAFBIRD' 'BORNEAN PHEASANT' 'BRANDT CORMARANT'
#  'BREWERS BLACKBIRD' 'BROWN CREPPER' 'BROWN NOODY' 'BROWN THRASHER'
#  'BUFFLEHEAD' 'BULWERS PHEASANT' 'BURCHELLS COURSER' 'BUSH TURKEY'
#  'CAATINGA CACHOLOTE' 'CACTUS WREN' 'CALIFORNIA CONDOR' 'CALIFORNIA GULL'
#  'CALIFORNIA QUAIL' 'CAMPO FLICKER' 'CANARY' 'CAPE GLOSSY STARLING'
#  'CAPE LONGCLAW' 'CAPE MAY WARBLER' 'CAPE ROCK THRUSH' 'CAPPED HERON'
#  'CAPUCHINBIRD' 'CARMINE BEE-EATER' 'CASPIAN TERN' 'CASSOWARY'
#  'CEDAR WAXWING' 'CERULEAN WARBLER' 'CHARA DE COLLAR' 'CHATTERING LORY'
#  'CHESTNET BELLIED EUPHONIA' 'CHINESE BAMBOO PARTRIDGE'
#  'CHINESE POND HERON' 'CHIPPING SPARROW' 'CHUCAO TAPACULO'
#  'CHUKAR PARTRIDGE' 'CINNAMON ATTILA' 'CINNAMON FLYCATCHER'
#  'CINNAMON TEAL' 'CLARKS NUTCRACKER' 'COCK OF THE  ROCK' 'COCKATOO'
#  'COLLARED ARACARI' 'COMMON FIRECREST' 'COMMON GRACKLE'
#  'COMMON HOUSE MARTIN' 'COMMON IORA' 'COMMON LOON' 'COMMON POORWILL'
#  'COMMON STARLING' 'COPPERY TAILED COUCAL' 'CRAB PLOVER' 'CRANE HAWK'
#  'CREAM COLORED WOODPECKER' 'CRESTED AUKLET' 'CRESTED CARACARA'
#  'CRESTED COUA' 'CRESTED FIREBACK' 'CRESTED KINGFISHER' 'CRESTED NUTHATCH'
#  'CRESTED OROPENDOLA' 'CRESTED SHRIKETIT' 'CRIMSON CHAT' 'CRIMSON SUNBIRD'
#  'CROW' 'CROWNED PIGEON' 'CUBAN TODY' 'CUBAN TROGON'
#  'CURL CRESTED ARACURI' 'D-ARNAUDS BARBET' 'DALMATIAN PELICAN'
#  'DARJEELING WOODPECKER' 'DARK EYED JUNCO' 'DARWINS FLYCATCHER'
#  'DAURIAN REDSTART' 'DEMOISELLE CRANE' 'DOUBLE BARRED FINCH'
#  'DOUBLE BRESTED CORMARANT' 'DOUBLE EYED FIG PARROT' 'DOWNY WOODPECKER'
#  'DUSKY LORY' 'DUSKY ROBIN' 'EARED PITA' 'EASTERN BLUEBIRD'
#  'EASTERN BLUEBONNET' 'EASTERN GOLDEN WEAVER' 'EASTERN MEADOWLARK'
#  'EASTERN ROSELLA' 'EASTERN TOWEE' 'EASTERN WIP POOR WILL'
#  'ECUADORIAN HILLSTAR' 'EGYPTIAN GOOSE' 'ELEGANT TROGON'
#  'ELLIOTS  PHEASANT' 'EMERALD TANAGER' 'EMPEROR PENGUIN' 'EMU'
#  'ENGGANO MYNA' 'EURASIAN BULLFINCH' 'EURASIAN GOLDEN ORIOLE'
#  'EURASIAN MAGPIE' 'EUROPEAN GOLDFINCH' 'EUROPEAN TURTLE DOVE'
#  'EVENING GROSBEAK' 'FAIRY BLUEBIRD' 'FAIRY PENGUIN' 'FAIRY TERN'
#  'FAN TAILED WIDOW' 'FASCIATED WREN' 'FIERY MINIVET' 'FIORDLAND PENGUIN'
#  'FIRE TAILLED MYZORNIS' 'FLAME BOWERBIRD' 'FLAME TANAGER' 'FRIGATE'
#  'GAMBELS QUAIL' 'GANG GANG COCKATOO' 'GILA WOODPECKER' 'GILDED FLICKER'
#  'GLOSSY IBIS' 'GO AWAY BIRD' 'GOLD WING WARBLER' 'GOLDEN BOWER BIRD'
#  'GOLDEN CHEEKED WARBLER' 'GOLDEN CHLOROPHONIA' 'GOLDEN EAGLE'
#  'GOLDEN PARAKEET' 'GOLDEN PHEASANT' 'GOLDEN PIPIT' 'GOULDIAN FINCH'
#  'GRANDALA' 'GRAY CATBIRD' 'GRAY KINGBIRD' 'GRAY PARTRIDGE'
#  'GREAT GRAY OWL' 'GREAT JACAMAR' 'GREAT KISKADEE' 'GREAT POTOO'
#  'GREAT TINAMOU' 'GREAT XENOPS' 'GREATER PEWEE' 'GREATOR SAGE GROUSE'
#  'GREEN BROADBILL' 'GREEN JAY' 'GREEN MAGPIE' 'GREY CUCKOOSHRIKE'
#  'GREY PLOVER' 'GROVED BILLED ANI' 'GUINEA TURACO' 'GUINEAFOWL'
#  'GURNEYS PITTA' 'GYRFALCON' 'HAMERKOP' 'HARLEQUIN DUCK' 'HARLEQUIN QUAIL'
#  'HARPY EAGLE' 'HAWAIIAN GOOSE' 'HAWFINCH' 'HELMET VANGA'
#  'HEPATIC TANAGER' 'HIMALAYAN BLUETAIL' 'HIMALAYAN MONAL' 'HOATZIN'
#  'HOODED MERGANSER' 'HOOPOES' 'HORNED GUAN' 'HORNED LARK' 'HORNED SUNGEM'
#  'HOUSE FINCH' 'HOUSE SPARROW' 'HYACINTH MACAW' 'IBERIAN MAGPIE'
#  'IBISBILL' 'IMPERIAL SHAQ' 'INCA TERN' 'INDIAN BUSTARD' 'INDIAN PITTA'
#  'INDIAN ROLLER' 'INDIAN VULTURE' 'INDIGO BUNTING' 'INDIGO FLYCATCHER'
#  'INLAND DOTTEREL' 'IVORY BILLED ARACARI' 'IVORY GULL' 'IWI' 'JABIRU'
#  'JACK SNIPE' 'JANDAYA PARAKEET' 'JAPANESE ROBIN' 'JAVA SPARROW'
#  'JOCOTOCO ANTPITTA' 'KAGU' 'KAKAPO' 'KILLDEAR' 'KING EIDER'
#  'KING VULTURE' 'KIWI' 'KOOKABURRA' 'LARK BUNTING' 'LAZULI BUNTING'
#  'LESSER ADJUTANT' 'LILAC ROLLER' 'LITTLE AUK' 'LOGGERHEAD SHRIKE'
#  'LONG-EARED OWL' 'MAGPIE GOOSE' 'MALABAR HORNBILL' 'MALACHITE KINGFISHER'
#  'MALAGASY WHITE EYE' 'MALEO' 'MALLARD DUCK' 'MANDRIN DUCK'
#  'MANGROVE CUCKOO' 'MARABOU STORK' 'MASKED BOOBY' 'MASKED LAPWING'
#  'MCKAYS BUNTING' 'MIKADO  PHEASANT' 'MOURNING DOVE' 'MYNA'
#  'NICOBAR PIGEON' 'NOISY FRIARBIRD' 'NORTHERN BEARDLESS TYRANNULET'
#  'NORTHERN CARDINAL' 'NORTHERN FLICKER' 'NORTHERN FULMAR'
#  'NORTHERN GANNET' 'NORTHERN GOSHAWK' 'NORTHERN JACANA'
#  'NORTHERN MOCKINGBIRD' 'NORTHERN PARULA' 'NORTHERN RED BISHOP'
#  'NORTHERN SHOVELER' 'OCELLATED TURKEY' 'OKINAWA RAIL'
#  'ORANGE BRESTED BUNTING' 'ORIENTAL BAY OWL' 'OSPREY' 'OSTRICH' 'OVENBIRD'
#  'OYSTER CATCHER' 'PAINTED BUNTING' 'PALILA' 'PARADISE TANAGER'
#  'PARAKETT  AKULET' 'PARUS MAJOR' 'PATAGONIAN SIERRA FINCH' 'PEACOCK'
#  'PEREGRINE FALCON' 'PHILIPPINE EAGLE' 'PINK ROBIN' 'POMARINE JAEGER'
#  'PUFFIN' 'PURPLE FINCH' 'PURPLE GALLINULE' 'PURPLE MARTIN'
#  'PURPLE SWAMPHEN' 'PYGMY KINGFISHER' 'QUETZAL' 'RAINBOW LORIKEET'
#  'RAZORBILL' 'RED BEARDED BEE EATER' 'RED BELLIED PITTA'
#  'RED BROWED FINCH' 'RED FACED CORMORANT' 'RED FACED WARBLER' 'RED FODY'
#  'RED HEADED DUCK' 'RED HEADED WOODPECKER' 'RED HONEY CREEPER'
#  'RED NAPED TROGON' 'RED TAILED HAWK' 'RED TAILED THRUSH'
#  'RED WINGED BLACKBIRD' 'RED WISKERED BULBUL' 'REGENT BOWERBIRD'
#  'RING-NECKED PHEASANT' 'ROADRUNNER' 'ROBIN' 'ROCK DOVE'
#  'ROSY FACED LOVEBIRD' 'ROUGH LEG BUZZARD' 'ROYAL FLYCATCHER'
#  'RUBY THROATED HUMMINGBIRD' 'RUDY KINGFISHER' 'RUFOUS KINGFISHER'
#  'RUFUOS MOTMOT' 'SAMATRAN THRUSH' 'SAND MARTIN' 'SANDHILL CRANE'
#  'SATYR TRAGOPAN' 'SCARLET CROWNED FRUIT DOVE' 'SCARLET IBIS'
#  'SCARLET MACAW' 'SCARLET TANAGER' 'SHOEBILL' 'SHORT BILLED DOWITCHER'
#  'SKUA' 'SMITHS LONGSPUR' 'SNOWY EGRET' 'SNOWY OWL' 'SNOWY PLOVER' 'SORA'
#  'SPANGLED COTINGA' 'SPLENDID WREN' 'SPOON BILED SANDPIPER' 'SPOONBILL'
#  'SPOTTED CATBIRD' 'SRI LANKA BLUE MAGPIE' 'STEAMER DUCK'
#  'STORK BILLED KINGFISHER' 'STRAWBERRY FINCH' 'STRIPED OWL'
#  'STRIPPED MANAKIN' 'STRIPPED SWALLOW' 'SUPERB STARLING'
#  'SWINHOES PHEASANT' 'TAILORBIRD' 'TAIWAN MAGPIE' 'TAKAHE' 'TASMANIAN HEN'
#  'TEAL DUCK' 'TIT MOUSE' 'TOUCHAN' 'TOWNSENDS WARBLER' 'TREE SWALLOW'
#  'TRICOLORED BLACKBIRD' 'TROPICAL KINGBIRD' 'TRUMPTER SWAN'
#  'TURKEY VULTURE' 'TURQUOISE MOTMOT' 'UMBRELLA BIRD' 'VARIED THRUSH'
#  'VEERY' 'VENEZUELIAN TROUPIAL' 'VERMILION FLYCATHER'
#  'VICTORIA CROWNED PIGEON' 'VIOLET GREEN SWALLOW' 'VIOLET TURACO'
#  'VULTURINE GUINEAFOWL' 'WALL CREAPER' 'WATTLED CURASSOW'
#  'WATTLED LAPWING' 'WHIMBREL' 'WHITE BROWED CRAKE' 'WHITE CHEEKED TURACO'
#  'WHITE CRESTED HORNBILL' 'WHITE NECKED RAVEN' 'WHITE TAILED TROPIC'
#  'WHITE THROATED BEE EATER' 'WILD TURKEY' 'WILSONS BIRD OF PARADISE'
#  'WOOD DUCK' 'YELLOW BELLIED FLOWERPECKER' 'YELLOW CACIQUE'
#  'YELLOW HEADED BLACKBIRD']

# %% [markdown]
# ##### A function to visualize images randomly

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

def view_random_image(target_dir, target_class):
  # setting up the image directory
  target_folder = target_dir + target_class

  #get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)

  #read image and plotting it
  img = mpimg.imread(target_folder + "/" + random_image[0] )
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off")

  print(f"Image shape: {img.shape}")
  
  return img

# %%
img = view_random_image(target_dir = "C:/Users/Ravindra KVB/Desktop/vamsi/B.TEC/IDP/New folder/train/",
                        target_class = "VICTORIA CROWNED PIGEON") # or we can write nike instead of converse to see converse examples
# Out:
# Image shape: (224, 224, 3)

# %%
import tensorflow as tf
img.shape #(width, height, colour channels)
# Out:
# (224, 224, 3)

# %% [markdown]
# ##### More visualization :D

# %%
plt.figure(figsize = (15,7))
plt.subplot(1,3,1)
steak_image = view_random_image("C:/Users/Ravindra KVB/Desktop/vamsi/B.TEC/IDP/New folder/train/", "UMBRELLA BIRD")
plt.subplot(1,3,2)
pizza_image = view_random_image("C:/Users/Ravindra KVB/Desktop/vamsi/B.TEC/IDP/New folder/train/", "YELLOW HEADED BLACKBIRD")
plt.subplot(1,3,3)
pizza_image = view_random_image("C:/Users/Ravindra KVB/Desktop/vamsi/B.TEC/IDP/New folder/train/", "INDIAN PITTA")
# Out:
# Image shape: (224, 224, 3)
# Image shape: (224, 224, 3)
# Image shape: (224, 224, 3)

# %% [markdown]
# ## 2. Data Preprocessing

# %%
import matplotlib.pyplot as plt
import pathlib, os, random
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow as tf

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Activation, BatchNormalization, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential

# %%
train_dir = "C:/Users/Ravindra KVB/Desktop/vamsi/B.TEC/IDP/New folder/train/"
test_dir = "C:/Users/Ravindra KVB/Desktop/vamsi/B.TEC/IDP/New folder/test/"
val_dir = "C:/Users/Ravindra KVB/Desktop/vamsi/B.TEC/IDP/New folder/valid/"

# %%
# Rescale
train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)
valid_datagen = ImageDataGenerator(rescale = 1./255)

# data transfer from directories to batches
train_data = train_datagen.flow_from_directory(directory = train_dir,
                                               batch_size= 32,
                                               target_size= (224,224),
                                               class_mode = "categorical")

test_data = test_datagen.flow_from_directory(directory = test_dir,
                                               batch_size = 32,
                                               target_size = (224,224),
                                               class_mode = "categorical")

val_data = valid_datagen.flow_from_directory(directory = val_dir,
                                               batch_size = 32,
                                               target_size = (224,224),
                                               class_mode = "categorical")
# Out:
# Found 70626 images belonging to 450 classes.
# Found 2250 images belonging to 450 classes.
# Found 2250 images belonging to 450 classes.

# %% [markdown]
# ## 3.Creating and fitting the Model

# %%
# 1. Create a base model with tf.keras.applications

base_model = tf.keras.applications.InceptionV3(include_top= False,)

# 2. Freeze the base model
base_model.trainable = False

#3. Create inputs into models
inputs = tf.keras.layers.Input(shape =(300,300,3), name = "input-layer")

#4. Rescaling
#x = tf.keras.layers.experimental.preprocessing.Rescaling(1/255.)(inputs)

#5. Pass the inputs 
x = base_model(inputs)
print(f"Shape after passing inputs through base model: {x.shape}")

# 6. Average pool the outputs of the base model
x = tf.keras.layers.GlobalAveragePooling2D(name = "global_average_pooling_layer")(x)
print(f"Shape after GlobalAveragePooling2D: {x.shape}")

#7. Create the output activation layer
outputs = tf.keras.layers.Dense(450, activation = "softmax", name = "output-layer")(x)

# 8. Combine the inputs with outputs into a model
model_0 = tf.keras.Model(inputs, outputs)

# 9. Compile the model
model_0.compile(loss = "categorical_crossentropy",
                optimizer = tf.keras.optimizers.Adam(learning_rate = 0.01),
                metrics = ["accuracy"])


history = model_0.fit(train_data,
                                 epochs=10,
                                 steps_per_epoch = len(train_data),
                                 validation_data = val_data,
                                 validation_steps = int(0.25*len(val_data)),)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 27s 0us/step
# Shape after passing inputs through base model: (None, 8, 8, 2048)
# Shape after GlobalAveragePooling2D: (None, 2048)
# Epoch 1/10
#  113/2208 [>.............................] - ETA: 1:23:39 - loss: 17.3526 - accuracy: 0.1239

# %%
model_0.summary()

# %%
model_0.evaluate(test_data)

# %%
def plot_loss_curves(history):

  loss = history.history["loss"]
  val_loss = history.history["val_loss"]

  accuracy = history.history["accuracy"]
  val_accuracy = history.history["val_accuracy"]

  epochs = range(len(history.history["loss"]))

  #plot loss
  plt.plot(epochs, loss, label = "training_loss")
  plt.plot(epochs, val_loss, label = "val_loss")
  plt.title("loss")
  plt.xlabel("epochs")
  plt.legend()

  #plot accuracy
  plt.figure() 
  plt.plot(epochs, accuracy, label = "training_accuracy")
  plt.plot(epochs, val_accuracy, label = "val_accuracy")
  plt.title("accuracy")
  plt.xlabel("epochs")
  plt.legend()

# %%
plot_loss_curves(history)

# %% [markdown]
# ## 4. Freeze top layers of Base Model

# %%
# To begin fine-tuning lets start by setting the last 10 layers as trainable

base_model.trainable = True

# Un-freeze last 10 layers
for layer in base_model.layers[:-10]:
  layer.trainable = False

# Recompile (we have to compile model every time there is a change)
model_0.compile(loss = "categorical_crossentropy",
                optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), # when fine-tuning you typically want to lower lr by 10x
                 metrics = ["accuracy"] )

# %%
# Check which layers are trainable
for layer_number, layer in enumerate(model_0.layers[1].layers):
  print(layer_number, layer.name, layer.trainable)

# %%
# Now we have unfrozen some of the layers on the top 
print(len(model_0.trainable_variables))

# %% [markdown]
# ## 5. Fine-Tuning and Refitting

# %%
initial_epochs = 10
fine_tune_epochs = initial_epochs + 1

# Refit the model
history_2 = model_0.fit(train_data,
                       epochs = fine_tune_epochs,
                       validation_data = val_data,
                       validation_steps = int(0.25*len(val_data)),
                       initial_epoch =  history.epoch[-1],) # Start the epoch where it left before

# %%
model_0.evaluate(test_data)

# %%
plot_loss_curves(history_2)

# %% [markdown]
# <p style="text-align:center;"><img src="data:image/jpeg;base64,..." alt="Girl in a jacket" width="500" height="600" class="center"></p>

# %% [markdown]
# **If you find the work beneficial, upvote it! I expect your feedbacks on the project. Thanks, Emre**
